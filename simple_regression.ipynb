# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
x=[2600,2800,3100,3400,3800,4000]
y=[5100000,5300000,5800000,6100000,6800000,7100000]

# %%
plt.scatter(x,y,marker='o')
plt.xlabel('Area')
plt.ylabel("Price")
plt.title("area-price graph")
# Out:
# Text(0.5, 1.0, 'area-price graph')

# %%
# a straight line touching every points is not possible
# a straight line drawn is called linear line

# %%
# perpendicular line drawn corresponding to x axis and y axis

#regression model works on this model
# y=mx+c

# y= output
# m= slope
# x= independent variable
# c= constant or y intercept on x

# a difference occurs between actual value and predicted value called errors

#if errors are less then it is a good model
